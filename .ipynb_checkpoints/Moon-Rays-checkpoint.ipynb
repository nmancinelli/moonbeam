# %% [markdown]
# ### Ray Paths and TT Curves for the Moon
#
# Written by *Nick Mancinelli*, July 2018

# %%
#Read in Alex's Weber model 
# %matplotlib inline

model_string  = 'khan'

import pandas as pd

if 'khan' in model_string:
    names = ['Depth_km', 'Vs','Vp','Density']
    df = pd.read_csv('%s.txt' % model_string, delim_whitespace = True, skiprows = 0, names = names)
    
else:
    names = ['Radius_meters','Density','Vp','Vs','Dummy','Dummy','Dummy','Dummy','Dummy']
    df = pd.read_csv('%s.txt' % model_string, delim_whitespace = True, skiprows = 3, names = names)


    #Adjust units
    df['Radius_km'] = df['Radius_meters']/1000.
    df['Vp'] = df['Vp']/1000.
    df['Vs'] = df['Vs']/1000.
    df['Density'] = df['Density']/1000.
    radius_max = df.Radius_km.tolist()[-1]
    df['Depth_km'] = radius_max - df['Radius_km']
    df = df.iloc[::-1]

#Write in .nd format for taup calculation
fout = open('%s.nd' % model_string,'w')

for irow, row in df.iterrows():
    string = '%4.0f %5.1f %5.1f %5.1f\n' % (row.Depth_km, row.Vp, row.Vs, row.Density)
    
    if irow < len(df.Depth_km.tolist()) and irow > 0:
        if df.loc[irow-1].Depth_km == row.Depth_km:
            if row.Depth_km > 30. and row.Depth_km < 45.:
                fout.write('mantle\n')
            elif row.Depth_km > 1400. and row.Depth_km < 1415.:
                fout.write('outer-core\n')
            elif row.Depth_km > 1490. and row.Depth_km < 1505. and 'khan' not in model_string:
                fout.write('inner-core\n')
            elif row.Depth_km > 1445. and row.Depth_km < 1455. and 'khan' in model_string:
                fout.write('outer-core\n')
            elif row.Depth_km > 1445. and row.Depth_km < 1455. and 'khan' in model_string:
                fout.write('outer-core\n')
        elif row.Depth_km > 1720. and row.Depth_km < 1730. and 'khan' in model_string:
            fout.write('inner-core\n')
    fout.write(string)
                
fout.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/mancinelli/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# /Users/mancinelli/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [71] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-321-d48c3befb006> in <module>()
#      31     fout.write(string)
#      32     if irow < len(df.Depth_km.tolist()) and irow > 0:
# ---> 33         if df.loc[irow+1].Depth_km == row.Depth_km:
#      34             if row.Depth_km > 30. and row.Depth_km < 45.:
#      35                 fout.write('mantle\n')
#
# /Users/mancinelli/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /Users/mancinelli/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# /Users/mancinelli/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1440                 raise
#    1441             except:
# -> 1442                 error()
#    1443
#    1444         return True
#
# /Users/mancinelli/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1427                                     "key")
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#    1431             try:
#
# KeyError: 'the label [71] is not in the [index]'

# %%
from matplotlib import pylab as plt

plt.figure()

lw = 2

plt.plot(df.Vs, df.Depth_km, label=r'$V_s$', lw = lw)
plt.plot(df.Vp, df.Depth_km, label=r'$V_p$', lw = lw)
plt.plot(df.Density, df.Depth_km, label=r'$\rho$', lw = lw)
_ = plt.ylim(max(df.Depth_km), min(df.Depth_km))
_ = plt.legend(loc='best')
_ = plt.ylabel('Depth (km)')
_ = plt.xlabel('Velocity (km/s), Density (g/cc)')

# %%
#Build taup model through obspy wrapper

import obspy
from obspy.taup import taup_create, TauPyModel
taup_create.build_taup_model('weber_minos.nd')
taup_create.build_taup_model('weber_minos_nopml.nd')
taup_create.build_taup_model('khan.nd')
model1 = TauPyModel(model="weber_minos")
model2 = TauPyModel(model="weber_minos_nopml")
model3 = TauPyModel(model="khan")
# Out:
# Building obspy.taup model for 'weber_minos.nd' ...
# Building obspy.taup model for 'weber_minos_nopml.nd' ...
# Building obspy.taup model for 'khan.nd' ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-316-fa7bdbbd7c64> in <module>()
#       5 taup_create.build_taup_model('weber_minos.nd')
#       6 taup_create.build_taup_model('weber_minos_nopml.nd')
# ----> 7 taup_create.build_taup_model('khan.nd')
#       8 model1 = TauPyModel(model="weber_minos")
#       9 model2 = TauPyModel(model="weber_minos_nopml")
#
# /Users/mancinelli/anaconda/lib/python3.6/site-packages/obspy/taup/taup_create.py in build_taup_model(filename, output_folder, verbose)
#     178     mod_create = TauPCreate(input_filename=filename,
#     179                             output_filename=output_filename)
# --> 180     mod_create.load_velocity_model()
#     181     mod_create.run()
#     182
#
# /Users/mancinelli/anaconda/lib/python3.6/site-packages/obspy/taup/taup_create.py in load_velocity_model(self)
#      52         if self.debug:
#      53             print("filename =", filename)
# ---> 54         self.v_mod = VelocityModel.read_velocity_file(filename)
#      55         if self.v_mod is None:
#      56             raise IOError("Velocity model file not found: " + filename)
#
# /Users/mancinelli/anaconda/lib/python3.6/site-packages/obspy/taup/velocity_model.py in read_velocity_file(cls, filename)
#     376         """
#     377         if filename.endswith(".nd"):
# --> 378             v_mod = cls.read_nd_file(filename)
#     379         elif filename.endswith(".tvel"):
#     380             v_mod = cls.read_tvel_file(filename)
#
# /Users/mancinelli/anaconda/lib/python3.6/site-packages/obspy/taup/velocity_model.py in read_nd_file(cls, filename)
#     556
#     557         if moho_depth is None:
# --> 558             raise ValueError("Moho depth is not specified in model file!")
#     559         if cmb_depth is None:
#     560             raise ValueError("CMB depth is not specified in model file!")
#
# ValueError: Moho depth is not specified in model file!

# %%
#Plot some ray paths

for model in [model1, model3]:
    arrivals = model.get_ray_paths(source_depth_in_km=0, distance_in_degree=160, phase_list=["S","SS","PS"])
    ax = arrivals.plot_rays(legend=True)

# %% [markdown]
# #### Print travel times
#
# for arrival in arrivals:
#     print(arrival, arrival.time/60.)

# %%
#Plot travel time curves

from obspy.taup import plot_travel_times

import matplotlib.pyplot as plt
plt.style.use('ggplot')



for iplt, model in enumerate(['weber_minos','weber_minos_nopml']):
    fig = plt.figure(figsize=(6, 6))
    ax = fig.add_subplot(1,1,1)
    ax.set_title(model)
    ax = plot_travel_times(model=model, 
                           source_depth=850, 
                           #phase_list=["S","ScS","SS"],
                           phase_list=["P","PcP","PP","PKiKP"],
                           #phase_list=["sS", "S","ScS","SS","SSS","SSSS","P","PKP","PKIKP","PcS","ScP","PcP","pS",'p','s'], 
                           npoints = 50,
                           ax=ax, fig=fig, verbose=True)
# Out:
# There were 0 epicentral distances without an arrival
# There were 0 epicentral distances without an arrival

# %%
for arrival in arrivals:
    print(arrival.name, arrival.time)
# Out:
# S 752.646329331
# SS 952.56765064
# SSS 1010.44913504
# SSSS 1047.48572745
# SS 1311.29723866
# SSS 1456.37750784
# SSSS 1522.78188764
# SSSS 2842.02957622
# SSSS 3031.1959846

# %%
#Lunar Geometrical Spreading
#
from numpy import arcsin

def get_energy_density(psph, dpsph_ddeldeg, theta1, theta2, deldeg):
    from numpy import cos, sin, pi
    num = psph * abs(dpsph_ddeldeg)
    delrad = deldeg * pi/180.
    den = cos(theta1) * cos(theta2) * sin(delrad)
    return num / den
    

for d0 in range(6,156,10):
    ddeldeg = 0.05
    print('Delta = %d degrees' % d0)
    print('   %5s %7s %7s' % ('Name', 'Time', 'Amp.'))

    source_depth = 0

    arrivals0    = model1.get_ray_paths(source_depth_in_km=source_depth, distance_in_degree=d0, phase_list=["s","sS","S","SS","SSS","SSSS"])
    arrivals_ptb = model1.get_ray_paths(source_depth_in_km=source_depth, distance_in_degree=d0+ddeldeg, phase_list=["s","sS","S","SS","SSS","SSSS"])

    for ii in range(len(arrivals0)):
        psph = arrivals0[ii].ray_param
        dpsph = arrivals_ptb[ii].ray_param - arrivals0[ii].ray_param
        dpsph_ddeldeg = dpsph/ddeldeg
        v1=0.5
        v2=0.5
        r1=1737.-source_depth
        r2=1737.
        theta1 = arcsin(psph*v1/r1)
        theta2 = arcsin(psph*v2/r2)

        energy_density = get_energy_density(psph, dpsph_ddeldeg, theta1, theta2, d0)
        
        string = '   %5s %7.2f %7.2f' % (arrivals0[ii].name, arrivals0[ii].time, energy_density**0.5)
        print(string)
# Out:
# Delta = 6 degrees
#     Name    Time    Amp.
#        S   66.46   20.54
#        S   70.14   34.01
#        S   72.18  200.50
#       SS   83.96   15.79
#       SS   92.54    6.81
#       SS   93.43  331.53
#      SSS   97.77    9.83
#        S  101.01   66.32
#       SS  101.04   33.18
#      SSS  101.05   22.19
#     SSSS  101.05   16.56
#        S  101.98  200.27
#       SS  105.99  373.02
#     SSSS  111.58    6.77
#      SSS  112.35  496.51
#     SSSS  120.70  571.68
#      SSS 2060.93   38.42
#      SSS 2099.53   38.67
#     SSSS 2270.20   39.79
#     SSSS 2310.28    4.47
#     SSSS 2310.34   15.26
#     SSSS 2327.97   39.81
#     SSSS 2356.74    7.80
#     SSSS 2357.16   13.90
# Delta = 16 degrees
#     Name    Time    Amp.
#        S  133.55   23.96
#       SS  159.82   11.02
#        S  163.65   35.34
#        S  163.78   22.18
#       SS  177.79   17.33
#       SS  180.38   57.11
#      SSS  185.92    6.62
#      SSS  191.66   11.29
#      SSS  198.84   85.09
#     SSSS  205.49    8.26
#     SSSS  212.01    4.35
#     SSSS  219.22  106.89
#       SS  269.26   33.36
#      SSS  269.38   22.26
#     SSSS  269.42   16.68
#       SS  270.32   55.66
#      SSS  272.91   84.72
#     SSSS  276.46  110.62
#      SSS 2027.20   23.16
#      SSS 2130.04   23.69
#     SSSS 2220.93   24.47
#     SSSS 2374.95   24.50
#     SSSS 2395.41    6.46
